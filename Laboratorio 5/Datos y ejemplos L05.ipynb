# %%
import pandas as pd
import geopandas as gpd

# %%
bd_predios = 'Datos/SII/predios/predios.csv'
df_predios = pd.read_csv(bd_predios)

# %%
df_predios.head()
# Out:
#    Comuna  Manzana  Predial                                 Dirección  \
# 0    1101        1        4  M LIRA 315
# 1    1101        1        5  M LIRA 315
# 2    1101        1        6  M LIRA 315
# 3    1101        1        8  M LIRA S/N TERMINAL PESQUERO
# 4    1101        1       10  MAXIMO LIRA 389
#
#    Avalúo fiscal  Contribución semestral Código de destino  Avalúo exento  \
# 0      182161078                       0                 O      182161078
# 1       80802644                       0                 O       80802644
# 2       23142416                       0                 O       23142416
# 3     1113981936                 6199310                 C              0
# 4      446950571                 2487282                 O              0
#
#    Comuna Rol Bien Común 1  Manzana Rol Bien Común 1  Predio Rol Bien Común 1  \
# 0                        0                         0                        0
# 1                        0                         0                        0
# 2                        0                         0                        0
# 3                        0                         0                        0
# 4                        0                         0                        0
#
#    Comuna Rol Bien Común 2  Manzana Rol Bien Común 2  Predio Rol Bien Común 2  \
# 0                        0                         0                        0
# 1                        0                         0                        0
# 2                        0                         0                        0
# 3                        0                         0                        0
# 4                        0                         0                        0
#
#    Superficie (m2)
# 0              926
# 1              566
# 2              126
# 3             8025
# 4             1588

# %%
# Filtramos la información de Arica = 1101

df_predios_arica = df_predios.loc[df_predios['Comuna'] == 1101]
df_predios_arica.head()
# Out:
#    Comuna  Manzana  Predial                                 Dirección  \
# 0    1101        1        4  M LIRA 315
# 1    1101        1        5  M LIRA 315
# 2    1101        1        6  M LIRA 315
# 3    1101        1        8  M LIRA S/N TERMINAL PESQUERO
# 4    1101        1       10  MAXIMO LIRA 389
#
#    Avalúo fiscal  Contribución semestral Código de destino  Avalúo exento  \
# 0      182161078                       0                 O      182161078
# 1       80802644                       0                 O       80802644
# 2       23142416                       0                 O       23142416
# 3     1113981936                 6199310                 C              0
# 4      446950571                 2487282                 O              0
#
#    Comuna Rol Bien Común 1  Manzana Rol Bien Común 1  Predio Rol Bien Común 1  \
# 0                        0                         0                        0
# 1                        0                         0                        0
# 2                        0                         0                        0
# 3                        0                         0                        0
# 4                        0                         0                        0
#
#    Comuna Rol Bien Común 2  Manzana Rol Bien Común 2  Predio Rol Bien Común 2  \
# 0                        0                         0                        0
# 1                        0                         0                        0
# 2                        0                         0                        0
# 3                        0                         0                        0
# 4                        0                         0                        0
#
#    Superficie (m2)
# 0              926
# 1              566
# 2              126
# 3             8025
# 4             1588

# %%
df_predios.shape
# Out:
# (7143489, 15)

# %%
df_predios_arica.shape
# Out:
# (69326, 15)

# %%
bd_lineas = 'Datos/SII/lineas_construccion/lineas_construccion.csv'
df_lineas = pd.read_csv(bd_lineas, low_memory=False)

# %%
df_lineas.head()
# Out:
#    Comuna  Manzana  Predial  Línea de construcción Material estructural  \
# 0    1101        1        4                      1                   B
# 1    1101        1        4                      2                   E
# 2    1101        1        4                      3                   C
# 3    1101        1        5                      1                   B
# 4    1101        1        5                      2                   GB
#
#    Calidad construcción  Año construcción  Superficie (m2) Código de destino  \
# 0                     4              1925              631                 O
# 1                     3              1925              201                 O
# 2                     3              1925               91                 O
# 3                     4              1925              213                 O
# 4                     2              1925               13                 V
#
#   Código de condición
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df_lineas_arica = df_lineas.loc[df_lineas['Comuna'] == 1101]

# %%
df_lineas_arica.head()
# Out:
#    Comuna  Manzana  Predial  Línea de construcción Material estructural  \
# 0    1101        1        4                      1                   B
# 1    1101        1        4                      2                   E
# 2    1101        1        4                      3                   C
# 3    1101        1        5                      1                   B
# 4    1101        1        5                      2                   GB
#
#    Calidad construcción  Año construcción  Superficie (m2) Código de destino  \
# 0                     4              1925              631                 O
# 1                     3              1925              201                 O
# 2                     3              1925               91                 O
# 3                     4              1925              213                 O
# 4                     2              1925               13                 V
#
#   Código de condición
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df_lineas.shape
# Out:
# (9503467, 10)

# %%
df_lineas_arica.shape
# Out:
# (102527, 10)

# %%
bd_mz_temuco = 'Datos/SII/manzanas/temuco/MZ_DR_TEMUCO.shp'
bd_mz_serena = 'Datos/SII/manzanas/La Serena/MZ_DR_LA_SERENA.shp'
bd_mz_valdivia = 'Datos/SII/manzanas/Valdivia/MZ_DR_VALDIVIA.shp'

gdf_mz_temuco = gpd.read_file(bd_mz_temuco)
gdf_mz_serena = gpd.read_file(bd_mz_serena)
gdf_mz_valdivia = gpd.read_file(bd_mz_valdivia)

# %%
gdf_mz_temuco.head()
# Out:
#    COMUNA  MANZ_SII NOM_COMUNA  CMN_MZ  \
# 0    9201         0     TEMUCO  9201-0
# 1    9201         0     TEMUCO  9201-0
# 2    9201         0     TEMUCO  9201-0
# 3    9201         0     TEMUCO  9201-0
# 4    9201         0     TEMUCO  9201-0
#
#                                             geometry
# 0  POLYGON ((193526.160 5711379.385, 193514.817 5...
# 1  POLYGON ((181913.307 5711303.936, 181876.173 5...
# 2  POLYGON ((181955.004 5711318.791, 181917.084 5...
# 3  POLYGON ((181944.688 5711442.897, 182001.340 5...
# 4  POLYGON ((182048.958 5711316.749, 182040.270 5...

# %%
gdf_mz_serena.head()
# Out:
#    COMUNA  MANZ_SII NOM_COMUNA  CMN_MZ  \
# 0    4101         0  LA SERENA  4101-0
# 1    4101         0  LA SERENA  4101-0
# 2    4101         0  LA SERENA  4101-0
# 3    4101         0  LA SERENA  4101-0
# 4    4101         0  LA SERENA  4101-0
#
#                                             geometry
# 0  POLYGON ((284585.326 6692023.794, 284564.749 6...
# 1  POLYGON ((284754.068 6692121.836, 284734.943 6...
# 2  POLYGON ((282660.166 6692351.356, 282654.731 6...
# 3  POLYGON ((282562.121 6692407.957, 282553.994 6...
# 4  POLYGON ((282722.857 6692418.146, 282722.883 6...

# %%
gdf_mz_valdivia.head()
# Out:
#    COMUNA  MANZ_SII NOM_COMUNA      CMN_MZ  \
# 0   10101      2479   VALDIVIA  10101-2479
# 1   10101      2479   VALDIVIA  10101-2479
# 2   10101      2480   VALDIVIA  10101-2480
# 3   10101      2481   VALDIVIA  10101-2481
# 4   10101      2482   VALDIVIA  10101-2482
#
#                                             geometry
# 0  POLYGON ((140420.571 5582055.706, 140416.907 5...
# 1  POLYGON ((140468.296 5582102.548, 140428.413 5...
# 2  POLYGON ((140199.197 5581838.426, 140186.504 5...
# 3  POLYGON ((140231.113 5581869.751, 140218.582 5...
# 4  POLYGON ((140268.722 5581906.665, 140255.917 5...

# %%
gdf_mz_temuco['NOM_COMUNA'].value_counts()
# Out:
# TEMUCO             4574
# VILLARRICA         1319
# LAUTARO            1010
# ANGOL               921
# PADRE LAS CASAS     832
# PUCON               698
# VICTORIA            640
# LONCOCHE            529
# TRAIGUEN            465
# CURACAUTIN          437
# COLLIPULLI          411
# PITRUFQUEN          405
# VILCUN              391
# NUEVA IMPERIAL      385
# CARAHUE             330
# CUNCO               315
# GORBEA              314
# FREIRE              271
# PUREN               249
# TEODORO SCHMIDT     249
# RENAICO             193
# SAAVEDRA            184
# TOLTEN              182
# ERCILLA             177
# LONQUIMAY           158
# PERQUENCO           141
# LUMACO              141
# CHOLCHOL            138
# LOS SAUCES          133
# GALVARINO           131
# MELIPEUCO            87
# CURARREHUE           77
# Name: NOM_COMUNA, dtype: int64

# %%
gdf_mz_serena['NOM_COMUNA'].value_counts()
# Out:
# COQUIMBO       3390
# LA SERENA      3124
# OVALLE         1746
# LOS VILOS       842
# RIO HURTADO     376
# Name: NOM_COMUNA, dtype: int64

# %%
gdf_mz_valdivia['NOM_COMUNA'].value_counts()
# Out:
# VALDIVIA    3094
# LA UNION     710
# Name: NOM_COMUNA, dtype: int64

# %%
gdf_mz_temuco.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_mz_serena.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_mz_valdivia.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_mz_valdivia.crs
# Out:
# <Projected CRS: EPSG:32719>
# Name: WGS 84 / UTM zone 19S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 72°W to 66°W - by country
# - bounds: (-72.0, -80.0, -66.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 19S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_mz_temuco.crs
# Out:
# <Projected CRS: EPSG:32719>
# Name: WGS 84 / UTM zone 19S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 72°W to 66°W - by country
# - bounds: (-72.0, -80.0, -66.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 19S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_mz_serena.crs
# Out:
# <Projected CRS: EPSG:32719>
# Name: WGS 84 / UTM zone 19S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 72°W to 66°W - by country
# - bounds: (-72.0, -80.0, -66.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 19S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bd_zonas_temuco = 'Datos/EOD/Zonas EOD/Temuco 2013/Zonificacion.shp' 
bd_zonas_serena = 'Datos/EOD/Zonas EOD/La Serena 2010/LaSerenaCoq_zonas.shp'
bd_zonas_valdivia = 'Datos/EOD/Zonas EOD/Valdivia 2013/Zonificaci¢n_Valdivia.shp'

zonas_temuco = gpd.read_file(bd_zonas_temuco)
zonas_serena = gpd.read_file(bd_zonas_serena)
zonas_valdivia = gpd.read_file(bd_zonas_valdivia)

# %%
zonas_temuco.head()
# Out:
#    ZONA                                           geometry
# 0    61  POLYGON ((706913.285 5709707.499, 707050.442 5...
# 1    39  POLYGON ((707070.230 5709551.260, 707061.896 5...
# 2     8  POLYGON ((706158.073 5709966.003, 706913.285 5...
# 3    85  POLYGON ((706332.804 5710498.122, 706158.073 5...
# 4    38  POLYGON ((706424.742 5710510.952, 706332.804 5...

# %%
zonas_serena.head()
# Out:
#    ID  ZONA     COMUNA        SUP_M2    SUP_HA MACROZONA  \
# 0  50    50  La Serena  478605.21278  47.86052         3
# 1  52    52  La Serena  645244.98328  64.52450         3
# 2  51    51  La Serena  454164.40018  45.41644         3
# 3  75    75  La Serena  785657.49141  78.56575         3
# 4  53    53  La Serena  292691.50178  29.26915         3
#
#                                             geometry
# 0  POLYGON ((285647.117 6689393.244, 285768.900 6...
# 1  POLYGON ((285837.835 6688524.111, 285930.428 6...
# 2  POLYGON ((285202.798 6688805.464, 285268.666 6...
# 3  POLYGON ((286196.843 6688244.348, 286227.781 6...
# 4  POLYGON ((285837.835 6688524.111, 285932.209 6...

# %%
zonas_valdivia.head()
# Out:
#    ID     AREA  ZONA                                           geometry
# 0  42  587.500    36  POLYGON ((649610.885 5592850.559, 649503.766 5...
# 1  81   88.500    37  POLYGON ((652022.160 5593003.512, 651901.870 5...
# 2  44  652.875    35  POLYGON ((651572.525 5592442.233, 651806.223 5...
# 3  43  318.625    34  POLYGON ((650808.948 5591781.976, 650998.390 5...
# 4  79    0.000    33  POLYGON ((653753.365 5593969.662, 654213.939 5...

# %%
zonas_temuco.crs
# Out:
# <Projected CRS: EPSG:32718>
# Name: WGS 84 / UTM zone 18S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 78°W to 72°W - by country
# - bounds: (-78.0, -80.0, -72.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 18S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
zonas_serena.crs
# Out:
# <Projected CRS: EPSG:32719>
# Name: WGS 84 / UTM zone 19S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 72°W to 66°W - by country
# - bounds: (-72.0, -80.0, -66.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 19S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
zonas_valdivia.crs
# Out:
# <Projected CRS: EPSG:32718>
# Name: WGS 84 / UTM zone 18S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 78°W to 72°W - by country
# - bounds: (-78.0, -80.0, -72.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 18S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
zonas_temuco.plot()
# Out:
# <AxesSubplot:>

# %%
zonas_serena.plot()
# Out:
# <AxesSubplot:>

# %%
zonas_valdivia.plot()
# Out:
# <AxesSubplot:>

# %%
from Herramientas import teselator as ts


grilla = ts.grid_teselation(10, 100, 10, 100, 2, 3, 32719)

# %%
grilla.head()
# Out:
#    cell                                           geometry  area
# 0     1  POLYGON ((10.000 100.000, 12.000 100.000, 12.0...   6.0
# 1     2  POLYGON ((10.000 97.000, 12.000 97.000, 12.000...   6.0
# 2     3  POLYGON ((10.000 94.000, 12.000 94.000, 12.000...   6.0
# 3     4  POLYGON ((10.000 91.000, 12.000 91.000, 12.000...   6.0
# 4     5  POLYGON ((10.000 88.000, 12.000 88.000, 12.000...   6.0

# %%
grilla.plot(edgecolor = 'black', figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
hexagonos = ts.hexagon_teselation(10, 100, 10, 100, 1, 32719)

# %%
hexagonos.head()
# Out:
#    cell                                           geometry      area
# 0     1  POLYGON ((10.000 100.000, 11.000 100.000, 11.5...  2.598076
# 1     2  POLYGON ((10.000 98.268, 11.000 98.268, 11.500...  2.598076
# 2     3  POLYGON ((10.000 96.536, 11.000 96.536, 11.500...  2.598076
# 3     4  POLYGON ((10.000 94.804, 11.000 94.804, 11.500...  2.598076
# 4     5  POLYGON ((10.000 93.072, 11.000 93.072, 11.500...  2.598076

# %%
hexagonos.plot(edgecolor = 'black', figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
xmin, ymin, xmax, ymax = zonas_temuco.total_bounds
# Out:
# array([ 691141.87611278, 5702968.03377816,  716515.63969954,
#        5716903.6206843 ])

# %%
xmin
# Out:
# 691141.8761127846

# %%
zonas_temuco.crs
# Out:
# <Projected CRS: EPSG:32718>
# Name: WGS 84 / UTM zone 18S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 78°W to 72°W - by country
# - bounds: (-78.0, -80.0, -72.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 18S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
celdas_temuco = ts.hexagon_teselation(xmin, xmax, ymin, ymax, 300, 32718)

# %%
ax = celdas_temuco.plot(edgecolor = 'black', figsize = (10,10))
zonas_temuco.plot(ax = ax, color = 'g', edgecolor = 'r', alpha = 0.5)
# Out:
# <AxesSubplot:>
